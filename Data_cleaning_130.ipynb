# %%
import pandas as pd
import csv

# %%
df = pd.read_csv('total_stars.csv')
df
# Out:
#     Unnamed: 0         Star_name         Distance   Mass         Radius  \
# 0            0               Sun      0.000015813      1              1
# 1            1            Sirius           0008.6    2.1          1.71´
# 2            2           Canopus             0310     15             71
# 3            3    Alpha Centauri           0004.4    1.1            1.2
# 4            4          Arcturus             0037    1.1             26
# ..         ...               ...              ...    ...            ...
# 92          92           WOH G64         0163,000    <20  1,540 - 1,730
# 93          93        TRAPPIST-1            039.6  0.089           0.12
# 94          94  2MASS J0523-1403            040.3   0.07          0.086
# 95          95    WISE 0855−0714            07.27  0.003              ?
# 96          96            Icarus  014,400,000,000     33              ?
#
#      Luminosity  Unnamed: 6  Star_name.1  Distance.1  Mass.1  Radius.1
# 0             1         NaN          NaN         NaN     NaN       NaN
# 1          25.4         NaN          NaN         NaN     NaN       NaN
# 2        13,500         NaN          NaN         NaN     NaN       NaN
# 3             2         NaN          NaN         NaN     NaN       NaN
# 4           170         NaN          NaN         NaN     NaN       NaN
# ..          ...         ...          ...         ...     ...       ...
# 92  340-589,000         NaN          NaN         NaN     NaN       NaN
# 93       0.0005         NaN          NaN         NaN     NaN       NaN
# 94      0.00013         NaN          NaN         NaN     NaN       NaN
# 95            ?         NaN          NaN         NaN     NaN       NaN
# 96      850,000         NaN          NaN         NaN     NaN       NaN
#
# [97 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Star_name', 'Distance', 'Mass', 'Radius', 'Luminosity',
#        'Unnamed: 6', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0','Unnamed: 6', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1','Luminosity'],axis=1,inplace=True)

# %%
df
# Out:
#            Star_name         Distance   Mass         Radius
# 0                Sun      0.000015813      1              1
# 1             Sirius           0008.6    2.1          1.71´
# 2            Canopus             0310     15             71
# 3     Alpha Centauri           0004.4    1.1            1.2
# 4           Arcturus             0037    1.1             26
# ..               ...              ...    ...            ...
# 92           WOH G64         0163,000    <20  1,540 - 1,730
# 93        TRAPPIST-1            039.6  0.089           0.12
# 94  2MASS J0523-1403            040.3   0.07          0.086
# 95    WISE 0855−0714            07.27  0.003              ?
# 96            Icarus  014,400,000,000     33              ?
#
# [97 rows x 4 columns]

# %%
final_data = df.dropna()
final_data
# Out:
#            Star_name         Distance   Mass         Radius
# 0                Sun      0.000015813      1              1
# 1             Sirius           0008.6    2.1          1.71´
# 2            Canopus             0310     15             71
# 3     Alpha Centauri           0004.4    1.1            1.2
# 4           Arcturus             0037    1.1             26
# ..               ...              ...    ...            ...
# 92           WOH G64         0163,000    <20  1,540 - 1,730
# 93        TRAPPIST-1            039.6  0.089           0.12
# 94  2MASS J0523-1403            040.3   0.07          0.086
# 95    WISE 0855−0714            07.27  0.003              ?
# 96            Icarus  014,400,000,000     33              ?
#
# [96 rows x 4 columns]

# %%
final_data.reset_index(drop=True,inplace = True)
final_data
# Out:
#            Star_name         Distance   Mass         Radius
# 0                Sun      0.000015813      1              1
# 1             Sirius           0008.6    2.1          1.71´
# 2            Canopus             0310     15             71
# 3     Alpha Centauri           0004.4    1.1            1.2
# 4           Arcturus             0037    1.1             26
# ..               ...              ...    ...            ...
# 91           WOH G64         0163,000    <20  1,540 - 1,730
# 92        TRAPPIST-1            039.6  0.089           0.12
# 93  2MASS J0523-1403            040.3   0.07          0.086
# 94    WISE 0855−0714            07.27  0.003              ?
# 95            Icarus  014,400,000,000     33              ?
#
# [96 rows x 4 columns]

# %%
final_data.to_csv('final_data.csv')

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Star_name  96 non-null     object
#  1   Distance   96 non-null     object
#  2   Mass       96 non-null     object
#  3   Radius     96 non-null     object
# dtypes: object(4)
# memory usage: 3.1+ KB

# %%
final_data.describe()
# Out:
#        Star_name  Distance Mass Radius
# count         96        96   96     96
# unique        96        89   79     87
# top     VFTS 352  0163,000  1.5      ?
# freq           1         3    3      3

# %%
final_data.head(5)
# Out:
#         Star_name     Distance Mass Radius
# 0             Sun  0.000015813    1      1
# 1          Sirius       0008.6  2.1  1.71´
# 2         Canopus         0310   15     71
# 3  Alpha Centauri       0004.4  1.1    1.2
# 4        Arcturus         0037  1.1     26

# %%
final_data.dtypes
# Out:
# Star_name    object
# Distance     object
# Mass         object
# Radius       object
# dtype: object
